# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Data=np.loadtxt('ex1data1.txt',delimiter=',')

# %%
X=Data[:,0]
Y=Data[:,1]

# %%
plt.plot(X,Y,'rx')
plt.xlabel('Population of the city in 10,000s ')
plt.ylabel('Profit in $10,000')
plt.grid()

# %%
x0=np.ones((len(X)))
X1=np.column_stack((x0,X))
theta=np.zeros(X1.shape[1])

# %%
iterations=1500
alpha=0.01

# %%
def ComputeCost(X,y,theta):
    m=len(y)
    J=(1/(2*m))*np.sum(np.power((np.matmul(X,theta)-y),2))
    return J

# %%
ComputeCost(X1,Y,theta)
# Out:
# 32.072733877455676

# %%
ComputeCost(X1,Y,np.array([-1,2]))
# Out:
# 54.24245508201238

# %%
def gradientDescent(X,y,the,alp,num_iters):
    m=len(y)
    J_history=np.zeros(num_iters)
    for i in range(0,num_iters):
        the[0]=the[0]-(alp/m)*np.dot((np.matmul(X,the)-y),X[:,0])
        the[1]=the[1]-(alp/m)*np.dot((np.matmul(X,the)-y),X[:,1])
        J_history[i]=ComputeCost(X,y,the)
    return theta, J_history

# %%
th,Jh=gradientDescent(X1,Y,theta,alpha,iterations)

# %%
plt.plot(Jh,'g*',label='Cost Function')
plt.xlabel('Iterations')
plt.ylabel(r'J($\theta$)')
plt.grid()
plt.legend()

# %%
th
# Out:
# array([-3.63606348,  1.16698916])

# %%
plt.plot(X1[:,1],np.matmul(X1,th),'*-',label='Linear Regression GD')
plt.plot(X,Y,'rx')
plt.xlabel('Population of the city in 10,000s ')
plt.ylabel('Profit in $10,000')
plt.grid()
plt.legend()
